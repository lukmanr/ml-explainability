# %%
#!pip install anchor_exp==0.0.0.5

# %%
import itertools
import anchor_explainer as anchor

# %%
names = [
  'price',
  'date_utc',
  'day',
  'hour',
  'prev_week_min',
  'prev_week_25th',
  'prev_week_50th',
  'prev_week_75th',
  'prev_week_max'
]
w_names = [
  'temperature',
  'wind_speed_100m',
  'wind_direction_100m',
  'air_density',
  'precipitation',
  'wind_gust',
  'radiation',
  'wind_speed',
  'wind_direction',
  'pressure'
]

w_names = [ ['loc'+str(i)+"_"+n for n in w_names] for i in range(18)]

w_names = list(itertools.chain.from_iterable(w_names))

names = names + w_names

# %%
explainer = anchor.Explainer()

# %%
explainer.load_data(
  gcs_path = 'gs://energyforecast/data/csv/MLDataTrain.csv',
  target_idx = 0,
  features_to_use = range(2,189),
  categorical_features = [2,3],
  feature_names = names,
  skip_first=True
)

# %%
explainer.create_cmle_client(
  gcp_project = 'energy-forecasting',
  gcp_model = 'energyforecaster',
  gcp_model_version = 'new_energy',
  padding = (2,0)
)

# %%
explainer.assess_model(sample = 50)
# Out:
# {'accuracy': 0.54}

# %%
rand_expl = explainer.explain_random_record() #, show_in_notebook = True)
rand_expl
# Out:
# {'anchor': u'hour = 0 AND 1.50 < loc17_temperature <= 7.90 AND prev_week_75th > 0.63 AND 50.10 < loc15_wind_direction_100m <= 114.60',
#  'coverage': 0.0014,
#  'precision': 1.0,
#  'prediction': '0.43 < price <= 0.51',
#  'record': [u'2',
#   u'0',
#   '0.041299999999999996',
#   '0.46390000000000003',
#   '0.533',
#   '0.64295',
#   '0.6701',
#   '13.2',
#   '6.1',
#   '226.3',
#   '1.16',
#   '0',
#   '11.2',
#   '0',
#   '3.1',
#   '222',
#   '952.6',
#   '9.1',
#   '1.5',
#   '312.45',
#   '1.15',
#   '0',
#   '1.4',
#   '0',
#   '0.9',
#   '308.1',
#   '932.8',
#   '14.4',
#   '4.8',
#   '305.1',
#   '1.22',
#   '0',
#   '4.1',
#   '0',
#   '2.9',
#   '299.1',
#   '1001',
#   '17.6',
#   '10.2',
#   '338.85',
#   '1.22',
#   '0',
#   '11.2',
#   '0',
#   '5.5',
#   '339.2',
#   '1016.9',
#   '4.2',
#   '3.6',
#   '216.14999999999998',
#   '1.05',
#   '0',
#   '2.3',
#   '0',
#   '2.7',
#   '220.8',
#   '850.5',
#   '10.9',
#   '2.7',
#   '295.4',
#   '1.14',
#   '0',
#   '2.5',
#   '0',
#   '2',
#   '248.5',
#   '928.7',
#   '16.1',
#   '5.4',
#   '302.5',
#   '1.2',
#   '0',
#   '3.1',
#   '0',
#   '2.3',
#   '298.7',
#   '989.7',
#   '17.3',
#   '3.1',
#   '201.4',
#   '1.22',
#   '0',
#   '2.6',
#   '0',
#   '1.9',
#   '198.6',
#   '1014.8',
#   '6.3',
#   '4.7',
#   '170.6',
#   '1.11',
#   '0',
#   '4.5',
#   '0',
#   '3.5',
#   '170.9',
#   '910.2',
#   '7.2',
#   '3.2',
#   '263.4',
#   '1.1',
#   '0',
#   '1.6',
#   '0',
#   '1.3',
#   '263.25',
#   '881.5',
#   '14.2',
#   '2',
#   '280',
#   '1.15',
#   '0',
#   '1.8',
#   '0',
#   '1.3',
#   '276.6',
#   '945.1',
#   '19.5',
#   '4.9',
#   '81.45',
#   '1.06',
#   '0',
#   '3.2',
#   '0',
#   '2.6',
#   '85.4',
#   '890.1',
#   '7.5',
#   '1.8',
#   '17.5',
#   '1.18',
#   '0',
#   '1.6',
#   '0',
#   '1.2',
#   '19.6',
#   '942.8',
#   '8.6',
#   '2.2',
#   '143.2',
#   '1.1',
#   '0',
#   '2',
#   '0',
#   '1.4',
#   '142.25',
#   '884',
#   '14.4',
#   '7.7',
#   '260.1',
#   '1.15',
#   '0',
#   '8.1',
#   '0',
#   '3.4',
#   '257.9',
#   '940.1',
#   '26.9',
#   '3.3',
#   '68.6',
#   '1.15',
#   '0',
#   '3',
#   '0',
#   '2.8',
#   '71.05',
#   '990.2',
#   '4.6',
#   '1.3',
#   '105.15',
#   '1.11',
#   '0',
#   '1.2',
#   '0',
#   '0.8',
#   '115.4',
#   '881.4',
#   '4.6',
#   '1.3',
#   '105.15',
#   '1.11',
#   '0',
#   '1.2',
#   '0',
#   '0.8',
#   '115.4',
#   '881.4']}

# %%
mod_record = ','.join(['5','12'] + rand_expl['record'][2:])
print(mod_record)
explainer.explain_record(mod_record
) #, show_in_notebook = True)
# Out:
# 5,12,0.041299999999999996,0.46390000000000003,0.533,0.64295,0.6701,13.2,6.1,226.3,1.16,0,11.2,0,3.1,222,952.6,9.1,1.5,312.45,1.15,0,1.4,0,0.9,308.1,932.8,14.4,4.8,305.1,1.22,0,4.1,0,2.9,299.1,1001,17.6,10.2,338.85,1.22,0,11.2,0,5.5,339.2,1016.9,4.2,3.6,216.14999999999998,1.05,0,2.3,0,2.7,220.8,850.5,10.9,2.7,295.4,1.14,0,2.5,0,2,248.5,928.7,16.1,5.4,302.5,1.2,0,3.1,0,2.3,298.7,989.7,17.3,3.1,201.4,1.22,0,2.6,0,1.9,198.6,1014.8,6.3,4.7,170.6,1.11,0,4.5,0,3.5,170.9,910.2,7.2,3.2,263.4,1.1,0,1.6,0,1.3,263.25,881.5,14.2,2,280,1.15,0,1.8,0,1.3,276.6,945.1,19.5,4.9,81.45,1.06,0,3.2,0,2.6,85.4,890.1,7.5,1.8,17.5,1.18,0,1.6,0,1.2,19.6,942.8,8.6,2.2,143.2,1.1,0,2,0,1.4,142.25,884,14.4,7.7,260.1,1.15,0,8.1,0,3.4,257.9,940.1,26.9,3.3,68.6,1.15,0,3,0,2.8,71.05,990.2,4.6,1.3,105.15,1.11,0,1.2,0,0.8,115.4,881.4,4.6,1.3,105.15,1.11,0,1.2,0,0.8,115.4,881.4
# {'anchor': u'hour = 12 AND 908.50 < loc8_pressure <= 911.70 AND 2.30 < loc2_wind_speed <= 3.50 AND loc3_wind_speed_100m > 8.40',
#  'coverage': 0.0,
#  'precision': 1.0,
#  'prediction': '0.51 < price <= 0.60',
#  'record': [u'5',
#   u'12',
#   '0.041299999999999996',
#   '0.46390000000000003',
#   '0.533',
#   '0.64295',
#   '0.6701',
#   '13.2',
#   '6.1',
#   '226.3',
#   '1.16',
#   '0',
#   '11.2',
#   '0',
#   '3.1',
#   '222',
#   '952.6',
#   '9.1',
#   '1.5',
#   '312.45',
#   '1.15',
#   '0',
#   '1.4',
#   '0',
#   '0.9',
#   '308.1',
#   '932.8',
#   '14.4',
#   '4.8',
#   '305.1',
#   '1.22',
#   '0',
#   '4.1',
#   '0',
#   '2.9',
#   '299.1',
#   '1001',
#   '17.6',
#   '10.2',
#   '338.85',
#   '1.22',
#   '0',
#   '11.2',
#   '0',
#   '5.5',
#   '339.2',
#   '1016.9',
#   '4.2',
#   '3.6',
#   '216.14999999999998',
#   '1.05',
#   '0',
#   '2.3',
#   '0',
#   '2.7',
#   '220.8',
#   '850.5',
#   '10.9',
#   '2.7',
#   '295.4',
#   '1.14',
#   '0',
#   '2.5',
#   '0',
#   '2',
#   '248.5',
#   '928.7',
#   '16.1',
#   '5.4',
#   '302.5',
#   '1.2',
#   '0',
#   '3.1',
#   '0',
#   '2.3',
#   '298.7',
#   '989.7',
#   '17.3',
#   '3.1',
#   '201.4',
#   '1.22',
#   '0',
#   '2.6',
#   '0',
#   '1.9',
#   '198.6',
#   '1014.8',
#   '6.3',
#   '4.7',
#   '170.6',
#   '1.11',
#   '0',
#   '4.5',
#   '0',
#   '3.5',
#   '170.9',
#   '910.2',
#   '7.2',
#   '3.2',
#   '263.4',
#   '1.1',
#   '0',
#   '1.6',
#   '0',
#   '1.3',
#   '263.25',
#   '881.5',
#   '14.2',
#   '2',
#   '280',
#   '1.15',
#   '0',
#   '1.8',
#   '0',
#   '1.3',
#   '276.6',
#   '945.1',
#   '19.5',
#   '4.9',
#   '81.45',
#   '1.06',
#   '0',
#   '3.2',
#   '0',
#   '2.6',
#   '85.4',
#   '890.1',
#   '7.5',
#   '1.8',
#   '17.5',
#   '1.18',
#   '0',
#   '1.6',
#   '0',
#   '1.2',
#   '19.6',
#   '942.8',
#   '8.6',
#   '2.2',
#   '143.2',
#   '1.1',
#   '0',
#   '2',
#   '0',
#   '1.4',
#   '142.25',
#   '884',
#   '14.4',
#   '7.7',
#   '260.1',
#   '1.15',
#   '0',
#   '8.1',
#   '0',
#   '3.4',
#   '257.9',
#   '940.1',
#   '26.9',
#   '3.3',
#   '68.6',
#   '1.15',
#   '0',
#   '3',
#   '0',
#   '2.8',
#   '71.05',
#   '990.2',
#   '4.6',
#   '1.3',
#   '105.15',
#   '1.11',
#   '0',
#   '1.2',
#   '0',
#   '0.8',
#   '115.4',
#   '881.4',
#   '4.6',
#   '1.3',
#   '105.15',
#   '1.11',
#   '0',
#   '1.2',
#   '0',
#   '0.8',
#   '115.4',
#   '881.4']}

# %%
explainer.explain_model(sample=3)
# Out:
#                                               anchor  coverage  precision  \
# 0  day = 5 AND 4.00 < loc5_wind_speed_100m <= 6.5...    0.0015        1.0
# 1  day = 2 AND loc1_radiation > 398.28 AND 988.40...    0.0012        1.0
# 2  day = 3 AND hour = 18 AND loc7_wind_direction_...    0.0000        1.0
#
#              prediction
# 0  0.51 < price <= 0.60
# 1  0.51 < price <= 0.60
# 2          price > 0.60
